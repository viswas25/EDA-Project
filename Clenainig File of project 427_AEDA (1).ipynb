# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv(r"flipkart_chimneys_456.csv")
df
# Out:
#                                           Product Name   Brand  Price  Rating  \
# 0    RUWA VIVA 60 BLACK Wall Mounted Black 800 CMH ...    RUWA   3578     3.8
# 1    Kaff KEC60A Curve Glass Chimney 60 CM Auto Cle...    Kaff  17490     4.3
# 2    FABER Hood Stella 3D IN HC SC FL BK 75 Auto Cl...   FABER   7399     3.7
# 3    Elica FLAT FL 900 MAX HAC LTW MS (FULL GRILL) ...   Elica  13999     4.3
# 4    FABER Hood Coral BLDC HC SC FL BK IN 90-T Auto...   FABER  17999     4.5
# ..                                                 ...     ...    ...     ...
# 451  Koche STARK 90 CM BLDC Auto Clean Wall Mounted...   Koche   7199     NaN
# 452  Kaff TANNIC DHC 60 Auto Clean Wall Mounted Bla...    Kaff   6576     NaN
# 453  Kaff Ambra DHC 90 SS Auto Clean Wall Mounted S...    Kaff  15552     NaN
# 454  Vidhi Solutions Real Plus 1350 Powerful Suctio...   Vidhi   6576     4.0
# 455  Maplin Combo of Kitchen Chimney T01 + 3 Burner...  Maplin  37264     4.0
#
# ...

# %%
df['price_log']=np.log1p(df['Price'])

# %%
sns.boxplot

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            399 non-null    float64
#  4   Offer             448 non-null    object
#  5   Review Count      409 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
#  8   price_log         456 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 32.2+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            399 non-null    float64
#  4   Offer             448 non-null    object
#  5   Review Count      409 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.6+ KB

# %%
df.head()
# Out:
#                                         Product Name  Brand  Price  Rating  \
# 0  RUWA VIVA 60 BLACK Wall Mounted Black 800 CMH ...   RUWA   3578     3.8
# 1  Kaff KEC60A Curve Glass Chimney 60 CM Auto Cle...   Kaff  17490     4.3
# 2  FABER Hood Stella 3D IN HC SC FL BK 75 Auto Cl...  FABER   7399     3.7
# 3  Elica FLAT FL 900 MAX HAC LTW MS (FULL GRILL) ...  Elica  13999     4.3
# 4  FABER Hood Coral BLDC HC SC FL BK IN 90-T Auto...  FABER  17999     4.5
#
#      Offer  Review Count Suction Capacity   Size
# 0  60% off         594.0          800 CMH  60 cm
# 1  64% off          26.0         1150 CMH  75 cm
# 2  48% off          46.0         1250 CMH  90 cm
# 3  49% off         102.0         1600 CMH  90 cm
# 4  43% off         139.0         1500 CMH  90 cm

# %%
df

# %%
df['price_log'].skew()
# Out:
# np.float64(-0.07469697807277076)

# %%
sns.boxplot(df['price_log'])
# Out:
# <Axes: ylabel='price_log'>

# %%
df['Price'].skew()
# Out:
# np.float64(1.2300695123707015)

# %%
df.head()
# Out:
#                                         Product Name  Brand  Price  Rating  \
# 0  RUWA VIVA 60 BLACK Wall Mounted Black 800 CMH ...   RUWA   3578     3.8
# 1  Kaff KEC60A Curve Glass Chimney 60 CM Auto Cle...   Kaff  17490     4.3
# 2  FABER Hood Stella 3D IN HC SC FL BK 75 Auto Cl...  FABER   7399     3.7
# 3  Elica FLAT FL 900 MAX HAC LTW MS (FULL GRILL) ...  Elica  13999     4.3
# 4  FABER Hood Coral BLDC HC SC FL BK IN 90-T Auto...  FABER  17999     4.5
#
#      Offer  Review Count Suction Capacity   Size
# 0  60% off         594.0          800 CMH  60 cm
# 1  64% off          26.0         1150 CMH  75 cm
# 2  48% off          46.0         1250 CMH  90 cm
# 3  49% off         102.0         1600 CMH  90 cm
# 4  43% off         139.0         1500 CMH  90 cm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            399 non-null    float64
#  4   Offer             448 non-null    object
#  5   Review Count      409 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.6+ KB

# %%
df.isna().sum() ## Raings,offer,review count ,size
# Out:
# Product Name         0
# Brand                0
# Price                0
# Rating              57
# Offer                8
# Review Count        47
# Suction Capacity     0
# Size                 1
# dtype: int64

# %%
df['Offer'].value_counts()
# Out:
# Offer
# 67% off    84
# 48% off    26
# 64% off    25
# 60% off    22
# 63% off    22
# 30% off    16
# 71% off    15
# 65% off    12
# 49% off    12
# 55% off    11
# 46% off    10
# 54% off    10
# 56% off     9
# 51% off     8
# 58% off     8
# 62% off     8
# 66% off     8
# 57% off     7
# 69% off     7
# 59% off     7
# 38% off     7
# 61% off     7
# 50% off     6
# 53% off     6
# 52% off     6
# 73% off     6
# 47% off     6
# 43% off     5
# 44% off     5
# 40% off     5
# 72% off     4
# 41% off     4
# 45% off     4
# 33% off     4
# 36% off     3
# 39% off     3
# 28% off     3
# 24% off     3
# 42% off     3
# 68% off     3
# 18% off     3
# 1% off      3
# 37% off     2
# 74% off     2
# 70% off     2
# 34% off     2
# 75% off     1
# 76% off     1
# 81% off     1
# 78% off     1
# 20% off     1
# 77% off     1
# 11% off     1
# 35% off     1
# 31% off     1
# 15% off     1
# 25% off     1
# 32% off     1
# 5% off      1
# 22% off     1
# Name: count, dtype: int64

# %%
df['Rating'].median()
# Out:
# 4.1

# %%
df.isna().sum()
# Out:
# Product Name         0
# Brand                0
# Price                0
# Rating              57
# Offer                8
# Review Count        47
# Suction Capacity     0
# Size                 1
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(df['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].median())

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 4.1    154
# 3.7     63
# 4.3     49
# 4.4     34
# 4.2     33
# 3.8     31
# 4.0     27
# 3.9     18
# 4.5      9
# 4.6      6
# 3.6      5
# 5.0      4
# 3.4      4
# 3.1      3
# 4.7      3
# 3.5      3
# 2.4      2
# 3.2      2
# 3.0      2
# 3.3      2
# 4.8      1
# 2.5      1
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# Product Name         0
# Brand                0
# Price                0
# Rating               0
# Offer                8
# Review Count        47
# Suction Capacity     0
# Size                 1
# dtype: int64

# %%
df.head()
# Out:
#                                         Product Name  Brand  Price  Rating  \
# 0  RUWA VIVA 60 BLACK Wall Mounted Black 800 CMH ...   RUWA   3578     3.8
# 1  Kaff KEC60A Curve Glass Chimney 60 CM Auto Cle...   Kaff  17490     4.3
# 2  FABER Hood Stella 3D IN HC SC FL BK 75 Auto Cl...  FABER   7399     3.7
# 3  Elica FLAT FL 900 MAX HAC LTW MS (FULL GRILL) ...  Elica  13999     4.3
# 4  FABER Hood Coral BLDC HC SC FL BK IN 90-T Auto...  FABER  17999     4.5
#
#      Offer  Review Count Suction Capacity   Size
# 0  60% off         594.0          800 CMH  60 cm
# 1  64% off          26.0         1150 CMH  75 cm
# 2  48% off          46.0         1250 CMH  90 cm
# 3  49% off         102.0         1600 CMH  90 cm
# 4  43% off         139.0         1500 CMH  90 cm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            456 non-null    float64
#  4   Offer             448 non-null    object
#  5   Review Count      409 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.6+ KB

# %%
## df['Price'] = df['Price'].fillna(0)

# %%
## df['Brand'] = df['Brand'].fillna(df['Brand'].mode()[0])

# %%
## df['Brand'] = df['Brand'].fillna('Unknown')

# %%
## df = df.fillna('np.nan')

# %%
df.isnull().sum()
# Out:
# Product Name         0
# Brand                0
# Price                0
# Rating               0
# Offer                8
# Review Count        47
# Suction Capacity     0
# Size                 1
# dtype: int64

# %%
df.shape
# Out:
# (456, 8)

# %%
df.head()
# Out:
#                                         Product Name  Brand  Price  Rating  \
# 0  RUWA VIVA 60 BLACK Wall Mounted Black 800 CMH ...   RUWA   3578     3.8
# 1  Kaff KEC60A Curve Glass Chimney 60 CM Auto Cle...   Kaff  17490     4.3
# 2  FABER Hood Stella 3D IN HC SC FL BK 75 Auto Cl...  FABER   7399     3.7
# 3  Elica FLAT FL 900 MAX HAC LTW MS (FULL GRILL) ...  Elica  13999     4.3
# 4  FABER Hood Coral BLDC HC SC FL BK IN 90-T Auto...  FABER  17999     4.5
#
#      Offer  Review Count Suction Capacity   Size
# 0  60% off         594.0          800 CMH  60 cm
# 1  64% off          26.0         1150 CMH  75 cm
# 2  48% off          46.0         1250 CMH  90 cm
# 3  49% off         102.0         1600 CMH  90 cm
# 4  43% off         139.0         1500 CMH  90 cm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            456 non-null    float64
#  4   Offer             448 non-null    object
#  5   Review Count      409 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.6+ KB

# %%
## df['Price']=df['Price'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            456 non-null    float64
#  4   Offer             448 non-null    object
#  5   Review Count      409 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.6+ KB

# %% [markdown]
# ## 23456789

# %%
df.isna().sum()
# Out:
# Product Name         0
# Brand                0
# Price                0
# Rating               0
# Offer                8
# Review Count        47
# Suction Capacity     0
# Size                 1
# dtype: int64

# %%
df['Offer']=df['Offer'].fillna(df['Offer'].mode()[0])

# %%
df['Offer'].isna().sum()
# Out:
# np.int64(0)

# %%
## df['Offer'].mode()[0]

# %%
sns.boxplot(df['Review Count'])
# Out:
# <Axes: ylabel='Review Count'>

# %%
df.isna().sum()
# Out:
# Product Name         0
# Brand                0
# Price                0
# Rating               0
# Offer                0
# Review Count        47
# Suction Capacity     0
# Size                 1
# dtype: int64

# %%
df['Review Count'].median()
# Out:
# 34.0

# %%
df['Review Count']=df['Review Count'].fillna(df['Review Count'].median())

# %%
df.isna().sum()
# Out:
# Product Name        0
# Brand               0
# Price               0
# Rating              0
# Offer               0
# Review Count        0
# Suction Capacity    0
# Size                1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      456 non-null    object
#  1   Brand             456 non-null    object
#  2   Price             456 non-null    int64
#  3   Rating            456 non-null    float64
#  4   Offer             456 non-null    object
#  5   Review Count      456 non-null    float64
#  6   Suction Capacity  456 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.6+ KB

# %%
df=df[~(df.isna().sum(axis=1)>=1)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 455 entries, 0 to 455
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      455 non-null    object
#  1   Brand             455 non-null    object
#  2   Price             455 non-null    int64
#  3   Rating            455 non-null    float64
#  4   Offer             455 non-null    object
#  5   Review Count      455 non-null    float64
#  6   Suction Capacity  455 non-null    object
#  7   Size              455 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.0+ KB

# %%
df.head()
# Out:
#                                         Product Name  Brand  Price  Rating  \
# 0  RUWA VIVA 60 BLACK Wall Mounted Black 800 CMH ...   RUWA   3578     3.8
# 1  Kaff KEC60A Curve Glass Chimney 60 CM Auto Cle...   Kaff  17490     4.3
# 2  FABER Hood Stella 3D IN HC SC FL BK 75 Auto Cl...  FABER   7399     3.7
# 3  Elica FLAT FL 900 MAX HAC LTW MS (FULL GRILL) ...  Elica  13999     4.3
# 4  FABER Hood Coral BLDC HC SC FL BK IN 90-T Auto...  FABER  17999     4.5
#
#      Offer  Review Count Suction Capacity   Size
# 0  60% off         594.0          800 CMH  60 cm
# 1  64% off          26.0         1150 CMH  75 cm
# 2  48% off          46.0         1250 CMH  90 cm
# 3  49% off         102.0         1600 CMH  90 cm
# 4  43% off         139.0         1500 CMH  90 cm

# %%
df['Product Name'].value_counts()
# Out:
# Product Name
# Amplesta Sereno Auto Clean T-Shape 90cm, Touch & Gesture Control, Filterless, Low Noise Auto Clean Wal...    19
# Amplesta Sereno Auto Clean T-Shape 60cm, Touch & Gesture Control, Filterless, Low Noise Auto Clean Wal...    19
# FABER Hood Stella 3D IN HC SC FL BK 75 Auto Clean Wall Mounted Black 1350 CMH Chimney                        18
# FABER HOOD MARS PB BF BK 60 Wall Mounted Black 1000 CMH Chimney                                              18
# FABER Hood-Alpine-FL HC BK 90 Auto Clean Semi Inclined| Touch & Gesture Control | Autoclean| Powerful ...    17
#                                                                                                              ..
# Sunflame Chimney Innova Titanium DX Jet Black Dry Auto-Clean 60 cm 1230m3/hr Auto Clean Wall Mounted B...     1
# Hindware Smart Appliances Ripple 60 IN Auto Clean | Curved Glass | Filterless | Touch Control | Motion...     1
# ...

# %%
df['Product Name'][0].split()
# Out:
# ['RUWA',
#  'VIVA',
#  '60',
#  'BLACK',
#  'Wall',
#  'Mounted',
#  'Black',
#  '800',
#  'CMH',
#  'Chimney']

# %%
product_name=[]
for i in df['Product Name']:
    product_name.append(i.split()[0])

# %%
product_name
# Out:
# ['RUWA',
#  'Kaff',
#  'FABER',
#  'Elica',
#  'FABER',
#  'Hindware',
#  'LIVPURE',
#  'Amplesta',
#  'FABER',
#  'Elica',
#  'Hindware',
#  'Amplesta',
#  'Elica',
#  'FABER',
#  'Hindware',
#  'Elica',
#  'FABER',
#  'Amplesta',
#  'LIVPURE',
#  'Hindware',
#  'Amplesta',
#  'ZENPURE',
#  'FABER',
#  'FABER',
#  'Glen',
#  'Amplesta',
#  'RUWA',
#  'Kaff',
#  'Whirlpool',
#  'FABER',
#  'Hindware',
#  'RUWA',
#  'Kenstar',
#  'Whirlpool',
#  'Elica',
#  'LIVPURE',
#  'Amplesta',
#  'Amplesta',
#  'Whirlpool',
#  'Whirlpool',
#  'RUWA',
#  'Hindware',
#  'Hindware',
#  'Beyond',
#  'SURYA',
#  'V-Guard',
#  'Hindware',
#  'Amplesta',
#  'Elica',
#  'Hindware',
#  'FABER',
#  'FABER',
#  'Hindware',
#  'Elica',
#  'Hindware',
#  'FABER',
#  'FABER',
#  'FABER',
#  'Elica',
#  'Elica',
#  'Amplesta',
#  'Amplesta',
#  'Hindware',
#  'LIVPURE',
#  'FABER',
#  'Kenstar',
#  'Koche',
#  'Koche',
#  'Hindware',
#  'FABER',
#  'Koche',
#  'Koche',
#  'Hindware',
#  'FABER',
#  'RUWA',
# ...

# %%
df['Product Name']=df['Product Name'].str.extract(r'^(\w+\s+\w+)')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13040\4081266383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Product Name']=df['Product Name'].str.extract(r'^(\w+\s+\w+)')

# %%
df.head()
# Out:
#   Product Name  Brand  Price  Rating    Offer  Review Count Suction Capacity  \
# 0    RUWA VIVA   RUWA   3578     3.8  60% off         594.0          800 CMH
# 1  Kaff KEC60A   Kaff  17490     4.3  64% off          26.0         1150 CMH
# 2   FABER Hood  FABER   7399     3.7  48% off          46.0         1250 CMH
# 3   Elica FLAT  Elica  13999     4.3  49% off         102.0         1600 CMH
# 4   FABER Hood  FABER  17999     4.5  43% off         139.0         1500 CMH
#
#     Size
# 0  60 cm
# 1  75 cm
# 2  90 cm
# 3  90 cm
# 4  90 cm

# %%
df=df.drop('Product_Name',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df=df.drop('Product_Name',axis=1)
#
# File D:\Users\User\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.head()

# %%
df.isna().sum()

# %%
df['Product Name'].value_counts()

# %%
df.info()

# %%
df['Product Name']

# %%
df[df.isnull().any(axis=1)]

# %%
df[df['Brand']=='V-Guard']

# %%
df[df['Size']== '60 cm']

# %%
df=df[~(df.isna().sum(axis=1)>1)]

# %%
df.info()

# %%
df.isna().sum()

# %%
df.shape

# %%
df.head()

# %%
df=df.dropna(subset=['Product Name'])

# %%
df.isna().sum()

# %%
df.info()

# %%
df.to_csv('Chimneys_Project_427_A.csv')

# %%
import os

# %%
os.listdir()

# %%
## df['Rating'].astype('float')

# %%
df['Rating'] = df['Rating'].replace('NA', np.nan)

# %%
df['Rating'] = df['Rating'].astype('float')

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())

# %%
df.info()

# %%
df.head()

# %%
df['Review Count'].astype('float')

# %%
df['Review Count'].value_counts()

# %%
df['Review Count']=df['Review Count'].replace('NA','np.nan')

# %%
df['Review Count'].astype('float')

# %%
df['Review Count'].value_counts()

# %%
df.info()

# %%
df.tail()

# %%
df['Review Count'] = df['Review Count'].fillna(df['Review Count'].mean())

# %%
df.tail()

# %%
df.info()

# %%
df.shape

# %%
df.isna().sum()

# %%
df['Offer'][1].split()[0]

# %%
df['Offer']=df['Offer'].str.replace('off', '', case=False).str.strip()

# %%
df.head()

# %%
df.isna().sum()

# %%
df.info()

# %%
df.head()

# %%
df['Offer']=df['Offer'].str.replace('%', '', case=False).str.strip()

# %%
df.info()

# %%
df.head()

# %%
df.tail()

# %%
df['Offer'].value_counts().sum()

# %%
df['Offer'].isna().sum()

# %%
df.info()
