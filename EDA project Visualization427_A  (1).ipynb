# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Chimneys_Project_427_A.csv")

# %%
df.shape
# Out:
# (451, 9)

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.shape
# Out:
# (451, 8)

# %% [markdown]
# ## UNivarient

# %%
df.head()
# Out:
#   Product Name  Brand  Price  Rating    Offer  Review Count Suction Capacity  \
# 0    RUWA VIVA   RUWA   3578     3.8  60% off         594.0          800 CMH
# 1  Kaff KEC60A   Kaff  17490     4.3  64% off          26.0         1150 CMH
# 2   FABER Hood  FABER   7399     3.7  48% off          46.0         1250 CMH
# 3   Elica FLAT  Elica  13999     4.3  49% off         102.0         1600 CMH
# 4   FABER Hood  FABER  17999     4.5  43% off         139.0         1500 CMH
#
#     Size
# 0  60 cm
# 1  75 cm
# 2  90 cm
# 3  90 cm
# 4  90 cm

# %%
sns.histplot(df['Price'],bins=30,kde=True,color='orange')
plt.title('Price Distribution of Chimneys')
plt.show()   ### Most product price btw 5000 and 20000

# %%
plt.hist(df['Rating'], bins=20)
plt.title('Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
sns.boxplot(df['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.distplot(df['Price'],bins=20)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9112\3732079937.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'],bins=20)
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.barplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
sns.kdeplot(df['Rating'])  ######
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.histplot(df['Offer'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 plt.histplot(df['Offer'])
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'histplot'

# %%
sns.histplot(df['Offer'],bins=20,kde=True)
# Out:
# <Axes: xlabel='Offer', ylabel='Count'>

# %%
plt.boxplot(df['Offer'])
plt.title('Boxplot of Ratings')
plt.xlabel('Rating')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.boxplot(df['Offer'])
#       2 plt.title('Boxplot of Ratings')
#       3 plt.xlabel('Rating')
#
# File D:\Users\User\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File D:\Users\User\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:295, in rename_parameter.<locals>.wrapper(*args, **kwargs)
#     290     warn_deprecated(
# ...

# %%
sns.barplot(df['Offer'].value_counts())
# Out:
# <Axes: xlabel='Offer', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      451 non-null    object
#  1   Brand             451 non-null    object
#  2   Price             451 non-null    int64
#  3   Rating            451 non-null    float64
#  4   Offer             451 non-null    object
#  5   Review Count      451 non-null    float64
#  6   Suction Capacity  451 non-null    object
#  7   Size              451 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
sns.histplot(df['Review Count'])   #######
# Out:
# <Axes: xlabel='Review Count', ylabel='Count'>

# %%
df.head()
# Out:
#   Product Name  Brand  Price  Rating    Offer  Review Count Suction Capacity  \
# 0    RUWA VIVA   RUWA   3578     3.8  60% off         594.0          800 CMH
# 1  Kaff KEC60A   Kaff  17490     4.3  64% off          26.0         1150 CMH
# 2   FABER Hood  FABER   7399     3.7  48% off          46.0         1250 CMH
# 3   Elica FLAT  Elica  13999     4.3  49% off         102.0         1600 CMH
# 4   FABER Hood  FABER  17999     4.5  43% off         139.0         1500 CMH
#
#     Size
# 0  60 cm
# 1  75 cm
# 2  90 cm
# 3  90 cm
# 4  90 cm

# %%
sns.boxplot(df['Offer'].dropna())
plt.title('Offer Percentage Distribution')
plt.xlabel('Offer (%)')
plt.ylabel('Count')
plt.show()

# %%
plt.boxplot(df['Offer'].dropna(), vert=False)
plt.title('Boxplot of Offer Percentage')
plt.xlabel('Offer (%)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 plt.boxplot(df['Offer'].dropna(), vert=False)
#       2 plt.title('Boxplot of Offer Percentage')
#       3 plt.xlabel('Offer (%)')
#
# File D:\Users\User\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
sns.histplot(df['Review Count'].dropna(), bins=20)
plt.title('Review Count Distribution')
plt.xlabel('Number of Reviews')   ######
plt.ylabel('Count')
plt.show()

# %%
plt.boxplot(df['Review Count'].dropna(), vert=False)
plt.title('Boxplot of Review Count')
plt.xlabel('Number of Reviews')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      451 non-null    object
#  1   Brand             451 non-null    object
#  2   Price             451 non-null    int64
#  3   Rating            451 non-null    float64
#  4   Offer             451 non-null    object
#  5   Review Count      451 non-null    float64
#  6   Suction Capacity  451 non-null    object
#  7   Size              451 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
size_counts = df['Size'].value_counts().sort_index()
sns.countplot(data=df,x=Size)
plt.title('Chimney Size Distribution')
plt.xlabel('Size (cm)')
plt.ylabel('Number of Products')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 size_counts = df['Size'].value_counts().sort_index()
# ----> 2 sns.countplot(data=df,x=Size)
#       3 plt.title('Chimney Size Distribution')
#       4 plt.xlabel('Size (cm)')
#
# NameError: name 'Size' is not defined

# %%
brand_counts = df['Brand'].value_counts()
plt.figure(figsize=(10, 5))
plt.bar(brand_counts.index, brand_counts.values)
plt.title('Number of Products by Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
brand_counts = df['Brand'].value_counts()
plt.figure(figsize=(10, 5))
plt.count(brand_counts.index, brand_counts.values)
plt.title('Number of Products by Brand')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 3
#       1 brand_counts = df['Brand'].value_counts()
#       2 plt.figure(figsize=(10, 5))
# ----> 3 plt.count(brand_counts.index, brand_counts.values)
#       4 plt.title('Number of Products by Brand')
#       5 plt.xlabel('Brand')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'count'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      451 non-null    object
#  1   Brand             451 non-null    object
#  2   Price             451 non-null    int64
#  3   Rating            451 non-null    float64
#  4   Offer             451 non-null    object
#  5   Review Count      451 non-null    float64
#  6   Suction Capacity  451 non-null    object
#  7   Size              451 non-null    object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 28.3+ KB

# %%
plt.hist(df['Offer'].dropna(), bins=20)
plt.title('Offer Percentage Distribution')
plt.xlabel('Offer (%)')
plt.ylabel('Number of Products')
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['Offer'].dropna(), bins=20, edgecolor='black')
plt.title('Offer Percentage Distribution')
plt.xlabel('Offer (%)')
plt.ylabel('Number of Products')
plt.xticks(range(0, int(df['Offer'].max()) + 10, 10))  # clean numeric x-axis labels
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 6
#       4 plt.xlabel('Offer (%)')
#       5 plt.ylabel('Number of Products')
# ----> 6 plt.xticks(range(0, int(df['Offer'].max()) + 10, 10))  # clean numeric x-axis labels
#       7 plt.show()
#
# ValueError: invalid literal for int() with base 10: '81% off'

# %%
plt.figure()
plt.hist(df['Suction Capacity'].dropna(), bins=15)
plt.title('Suction Capacity Distribution')
plt.xlabel('Suction Capacity (CMH)')
plt.ylabel('Number of Products')
plt.show()

# %%
plt.figure()
plt.boxplot(df['Suction Capacity'].dropna(), vert=False)
plt.title('Boxplot of Suction Capacity')
plt.xlabel('Suction Capacity (CMH)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[80], line 2
#       1 plt.figure()
# ----> 2 plt.boxplot(df['Suction Capacity'].dropna(), vert=False)
#       3 plt.title('Boxplot of Suction Capacity')
#       4 plt.xlabel('Suction Capacity (CMH)')
#
# File D:\Users\User\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# ...

# %%
size_counts = df['Size'].value_counts().sort_index()
plt.figure(figsize=(10,8))
plt.bar(size_counts.index.astype(str), size_counts.values)
plt.title('Chimney Size Distribution')
plt.xlabel('Size (cm)')
plt.ylabel('Number of Products')
plt.show()
plt.

# %%
plt.figure(figsize=(8,5))
plt.hist(df['Offer'].dropna(), bins=20, color='lightcoral', edgecolor='black')
plt.title('Univariate: Offer Percentage Distribution')
plt.xlabel('Offer (%)')
plt.ylabel('Number of Products')
plt.xticks(range(0, int(df['Offer'].max()) + 10, 10))
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 6
#       4 plt.xlabel('Offer (%)')
#       5 plt.ylabel('Number of Products')
# ----> 6 plt.xticks(range(0, int(df['Offer'].max()) + 10, 10))
#       7 plt.grid(True, alpha=0.3)
#       8 plt.show()
#
# ValueError: invalid literal for int() with base 10: '81% off'

# %%
offers_clean = df['Offer'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)

plt.figure(figsize=(8,5))
plt.hist(offers_clean.dropna(), bins=20, color='lightcoral', edgecolor='black')
plt.title('Univariate: Offer Percentage Distribution')
plt.xlabel('Offer (%)')
plt.ylabel('Number of Products')
plt.xticks(range(0, int(offers_clean.max()) + 10, 10))   ######
plt.grid(True, alpha=0.3)
plt.show()

# %%
df['Size'] = df['Size'].astype(str).str.extract(r'(\d+\.?\d*)').astype(float)
size_counts = df['Size'].value_counts().sort_index()

plt.figure(figsize=(10,6))
plt.bar(size_counts.index.astype(str), size_counts.values, color='skyblue', edgecolor='black')
plt.title('Univariate: Chimney Size Distribution')
plt.xlabel('Size (cm)')
plt.ylabel('Number of Products')
plt.xticks(rotation=45)
plt.grid(True, axis='y', alpha=0.3) #################

# Annotate each bar with its value
##for i, val in enumerate(size_counts.values):
    ##plt.text(i, val + 2, str(int(val)), ha='center', fontsize=10)

plt.show()

# %%
brand_counts = df['Brand'].value_counts()

plt.figure(figsize=(15,10))
plt.bar(brand_counts.index, brand_counts.values, color='mediumseagreen', edgecolor='black')
plt.title('Univariate: Number of Products by Brand')
plt.xlabel('Brand')
plt.ylabel('Number of Products')    #### tell us which brand is saled most 
plt.xticks(rotation=60, fontsize=9)
plt.grid(True, axis='y', alpha=0.3)

# %% [markdown]
# ## Bie

# %%
sns.scatterplot(df['Price'],df['Rating'],alpha=0.7,color='teal', edgecolor='black')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 sns.scatterplot(df['Price'],df['Rating'],alpha=0.7,color='teal', edgecolor='black')
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Price', y='Rating', data=df, alpha=0.7, color='teal', edgecolor='black')
plt.title('Bivariate: Price vs Rating')
plt.xlabel('Price (₹)')
plt.ylabel('Rating')          ############
plt.grid(True, alpha=0.3)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      451 non-null    object
#  1   Brand             451 non-null    object
#  2   Price             451 non-null    int64
#  3   Rating            451 non-null    float64
#  4   Offer             451 non-null    object
#  5   Review Count      451 non-null    float64
#  6   Suction Capacity  451 non-null    object
#  7   Size              451 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 28.3+ KB

# %%
plt.figure(figsize=(18,10))
sns.scatterplot(x='Suction Capacity', y='Offer', data=df, alpha=0.7, color='teal', edgecolor='black')
plt.title('Bivariate: offer vs price')
plt.xlabel('Offer')
plt.ylabel('Price')    ##### doubt 
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      451 non-null    object
#  1   Brand             451 non-null    object
#  2   Price             451 non-null    int64
#  3   Rating            451 non-null    float64
#  4   Offer             451 non-null    object
#  5   Review Count      451 non-null    float64
#  6   Suction Capacity  451 non-null    object
#  7   Size              451 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 28.3+ KB

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x='Suction Capacity', y='Rating', data=df, alpha=0.7, color='purple', edgecolor='black')
plt.title('Bivariate: Suction Capacity vs Rating')
plt.xlabel('Suction Capacity (CMH)')
plt.ylabel('Rating')
plt.grid(True, alpha=0.3)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.boxplot([df.loc[df['Size'] == s, 'Suction Capacity'] for s in sorted(df['Size'].dropna().unique())],
            labels=sorted(df['Size'].dropna().unique().astype(int)))
plt.title('Bivariate: Size vs Suction Capacity')
plt.xlabel('Chimney Size (cm)')
plt.ylabel('Suction Capacity (CMH)')
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_648\874750602.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df.loc[df['Size'] == s, 'Suction Capacity'] for s in sorted(df['Size'].dropna().unique())],
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize=(8,6))
# ----> 2 plt.boxplot([df.loc[df['Size'] == s, 'Suction Capacity'] for s in sorted(df['Size'].dropna().unique())],
#       3             labels=sorted(df['Size'].dropna().unique().astype(int)))
#       4 plt.title('Bivariate: Size vs Suction Capacity')
#       5 plt.xlabel('Chimney Size (cm)')
#
# File D:\Users\User\anaconda3\Lib\site-packages\matplotlib\_api\deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
# ...

# %%
plt.figure(figsize=(10,6))
df.boxplot(column='Brand', by='Rating', rot=45)
plt.title('Bivariate: Rating Distribution by Brand')
plt.suptitle('')
plt.xlabel('Brand')
plt.ylabel('Rating')
plt.grid(True, axis='y', alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 plt.figure(figsize=(10,6))
# ----> 2 df.boxplot(column='Brand', by='Rating', rot=45)
#       3 plt.title('Bivariate: Rating Distribution by Brand')
#       4 plt.suptitle('')
#
# File D:\Users\User\anaconda3\Lib\site-packages\pandas\plotting\_core.py:533, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)
#     530     **kwargs,
#     531 ):
#     532     plot_backend = _get_plot_backend(backend)
# --> 533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#     536         by=by,
#     537         ax=ax,
#     538         fontsize=fontsize,
#     539         rot=rot,
# ...

# %%
suction_clean = df['Suction Capacity'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)

plt.figure(figsize=(10,6))
sns.scatterplot(
    x=suction_clean,
    y=df['Rating'],
    hue=df['Brand'],          # hue differentiates brands by color,          # color palette
    alpha=0.7
)
plt.title('Bivariate: Suction Capacity vs Rating (Hue = Brand)')   #################
plt.xlabel('Suction Capacity (CMH)')
plt.ylabel('Rating')
plt.legend(title='Brand', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.show()

# %%
offers_clean = df['Offer'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)

plt.figure(figsize=(8,6))
sns.scatterplot(x=offers_clean, y=df['Price'], color='orange', alpha=0.7)
plt.title('Bivariate: Offer vs Price')
plt.xlabel('Offer (%)')
plt.ylabel('Price (₹)')  ###########
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## Multi

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='suction_bins', y='Rating', data=df, palette='coolwarm')
plt.title('Suction Capacity Range vs Rating Distribution')
plt.xlabel('Suction Capacity Range (CMH)')
plt.ylabel('Rating')
plt.grid(True, axis='y', alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 plt.figure(figsize=(8,6))
# ----> 2 sns.boxplot(x='suction_bins', y='Rating', data=df, palette='coolwarm')
#       3 plt.title('Suction Capacity Range vs Rating Distribution')
#       4 plt.xlabel('Suction Capacity Range (CMH)')
#
# File D:\Users\User\anaconda3\Lib\site-packages\seaborn\categorical.py:1597, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1589 def boxplot(
#    1590     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1591     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1594     legend="auto", ax=None, **kwargs
#    1595 ):
# ...

# %%
df.head()
# Out:
#   Product Name  Brand  Price  Rating    Offer  Review Count Suction Capacity  \
# 0    RUWA VIVA   RUWA   3578     3.8  60% off         594.0          800 CMH
# 1  Kaff KEC60A   Kaff  17490     4.3  64% off          26.0         1150 CMH
# 2   FABER Hood  FABER   7399     3.7  48% off          46.0         1250 CMH
# 3   Elica FLAT  Elica  13999     4.3  49% off         102.0         1600 CMH
# 4   FABER Hood  FABER  17999     4.5  43% off         139.0         1500 CMH
#
#    Size
# 0  60.0
# 1  75.0
# 2  90.0
# 3  90.0
# 4  90.0

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 4.1    152
# 3.7     63
# 4.3     49
# 4.4     34
# 4.2     32
# 3.8     31
# 4.0     26
# 3.9     18
# 4.5      8
# 4.6      6
# 3.6      5
# 5.0      4
# 3.4      4
# 3.1      3
# 4.7      3
# 3.5      3
# 2.4      2
# 3.2      2
# 3.0      2
# 3.3      2
# 4.8      1
# 2.5      1
# Name: count, dtype: int64

# %%
df['Rating_Performance'] = pd.cut(df['Rating'],bins = [1,2,3,4,5],labels=['Low','Average','Good','Excellent'])

# %%
df['suction_bins'] = pd.cut(df['Suction_clean'],bins = [0,500,1000,1500,2000],labels=['0-500 CMH','500 - 1000 CMH','1000 - 1500 CMH','1500 -2000 CHM'])

# %%
df.head()
# Out:
#   Product Name  Brand  Price  Rating    Offer  Review Count Suction Capacity  \
# 0    RUWA VIVA   RUWA   3578     3.8  60% off         594.0          800 CMH
# 1  Kaff KEC60A   Kaff  17490     4.3  64% off          26.0         1150 CMH
# 2   FABER Hood  FABER   7399     3.7  48% off          46.0         1250 CMH
# 3   Elica FLAT  Elica  13999     4.3  49% off         102.0         1600 CMH
# 4   FABER Hood  FABER  17999     4.5  43% off         139.0         1500 CMH
#
#    Size  Offer_clean  Suction_clean Rating_Performance     suction_bins
# 0  60.0         60.0          800.0               Good   500 - 1000 CMH
# 1  75.0         64.0         1150.0          Excellent  1000 - 1500 CMH
# 2  90.0         48.0         1250.0               Good  1000 - 1500 CMH
# 3  90.0         49.0         1600.0          Excellent   1500 -2000 CHM
# 4  90.0         43.0         1500.0          Excellent  1000 - 1500 CMH

# %%
sns.barplot(data = df ,x = 'Rating_Performance' , y = 'Price',hue='suction_bins') ### Multi
# Out:
# <Axes: xlabel='Rating_Performance', ylabel='Price'>

# %%
sns.relplot(data = df , x= 'Rating', y = 'Suction_clean',hue='suction_bins') ## Multi

# %%
df['Suction Capacity'].value_counts()
# Out:
# Suction Capacity
# 1350 CMH                       101
# 1200 CMH                        61
# 1250 CMH                        59
# 1500 CMH                        49
# 800 CMH                         34
# 1400 CMH                        23
# 1100 CMH                        21
# 1150 CMH                        20
# 1000 CMH                        19
# 1600 CMH                        11
# 1300 CMH                        11
# 1450 CMH                        11
# 1425 CMH                         4
# 1550 CMH                         4
# 1408 CMH                         3
# 880 CMH                          2
# 1800 CMH                         2
# 1626 CMH                         2
# 1700 CMH                         2
# 1050 CMH                         2
# 900 CMH                          1
# Suction Capacity: 1100 m3/h      1
# Suction Capacity: 1200 CHM       1
# 1417 CMH                         1
# 2000 CMH                         1
# Suction Capacity: 1080 m³/h      1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 451 entries, 0 to 450
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product Name      451 non-null    object
#  1   Brand             451 non-null    object
#  2   Price             451 non-null    int64
#  3   Rating            451 non-null    float64
#  4   Offer             451 non-null    object
#  5   Review Count      451 non-null    float64
#  6   Suction Capacity  451 non-null    object
#  7   Size              451 non-null    float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 28.3+ KB

# %%
sns.barplot(data=df,x='

# %%
df['Offer_clean'] = df['Offer'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)
df['Suction_clean'] = df['Suction Capacity'].astype(str).str.extract(r'(\d+\.?\d*)')[0].astype(float)

# Select only numeric columns
num_df = df[['Price', 'Rating', 'Offer_clean', 'Review Count', 'Suction_clean', 'Size']]

# Compute correlation
corr = num_df.corr()

# Plot
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f")   #### in this code only extra column is added 
plt.title('Multivariate: Correlation Heatmap')
plt.show()

# %%
df.head()
# Out:
#   Product Name  Brand  Price  Rating    Offer  Review Count Suction Capacity  \
# 0    RUWA VIVA   RUWA   3578     3.8  60% off         594.0          800 CMH
# 1  Kaff KEC60A   Kaff  17490     4.3  64% off          26.0         1150 CMH
# 2   FABER Hood  FABER   7399     3.7  48% off          46.0         1250 CMH
# 3   Elica FLAT  Elica  13999     4.3  49% off         102.0         1600 CMH
# 4   FABER Hood  FABER  17999     4.5  43% off         139.0         1500 CMH
#
#    Size  Offer_clean  Suction_clean Rating_Performance     suction_bins
# 0  60.0         60.0          800.0               Good   500 - 1000 CMH
# 1  75.0         64.0         1150.0          Excellent  1000 - 1500 CMH
# 2  90.0         48.0         1250.0               Good  1000 - 1500 CMH
# 3  90.0         49.0         1600.0          Excellent   1500 -2000 CHM
# 4  90.0         43.0         1500.0          Excellent  1000 - 1500 CMH

# %%
df.to_csv('final_data_set_project_427-A.csv')
